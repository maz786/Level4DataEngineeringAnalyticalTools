# %% [markdown]
# **<u>Customer Sales</u>**

# %%
import pandas as pd
import matplotlib.pyplot as plt

customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

sales_by_customer = sales_df.groupby('CustomerID').size().reset_index(name='NumSales')

customer_loyalty_df = pd.merge(customers_df, sales_by_customer, on='CustomerID')

plt.bar(customer_loyalty_df['FirstName'], customer_loyalty_df['NumSales'])
plt.show()

# %% [markdown]
# The sales data is grouped by customer ID, the number of sales for each customer is counted, and the sales data is then combined with the customer data. The resulting data is then shown visually using a bar chart, where the y-axis represents the number of sales for each client and the x-axis the first names of the customers.
#
# This code could be applied in a number of ways to conduct analysis, make forecasts, or find patterns or trends. For instance:
#
# You can easily examine which customers have made the most purchases and spot any trends or patterns in their buying behaviour by viewing the data in a bar chart.
#
# Customers who have made numerous purchases can be identified using the data, and you can then promote to or enrol them in loyalty programmes.
#
# Based on certain consumers' prior purchasing patterns, you can utilise the data to anticipate future sales for those customers.
#
# The data can be used to spot trends or patterns in client buying habits, such as times of the year when particular products are more popular or characteristics shared by customers who shop frequently.
#
# In general, this code offers a mechanism to examine and display information on consumer purchase behaviour.
