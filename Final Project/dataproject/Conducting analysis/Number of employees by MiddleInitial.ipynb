# %% [markdown]
# **<u>Number of employees by MiddleInitial</u>**

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Read the Employees database into a DataFrame
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
# Create a bar plot showing the number of employees in each MiddleInitial group
employees_df['MiddleInitial'].value_counts().plot(kind='bar')
plt.xlabel('MiddleInitial')
plt.ylabel('Number of employees')
plt.title('Number of employees by MiddleInitial')
plt.show()
