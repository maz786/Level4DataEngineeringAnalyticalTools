# %% [markdown]
# **<u>Customer loyalty</u>**

# %%
import pandas as pd
import matplotlib.pyplot as plt

customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

sales_by_customer = sales_df.groupby('CustomerID').size().reset_index(name='NumSales')

customer_loyalty_df = pd.merge(customers_df, sales_by_customer, on='CustomerID')

plt.pie(customer_loyalty_df['NumSales'], labels=customer_loyalty_df['FirstName'])
plt.show()

# %% [markdown]
# The following methods for doing analysis, making predictions, and seeing trends and patterns in the data could be done using this code:
#
# Analyzing customer loyalty: You can determine which customers are the most devoted to your company by classifying the sales data by customer and tallying the number of sales for each client. You may utilise this data to reward your most devoted consumers or to focus your marketing efforts.
#
# Forecasting sales: By looking at how many sales each customer generates, you might be able to spot trends or patterns in their behaviour that you can then utilise to project future sales.
#
# Finding patterns and trends in customer behaviour: By studying the data in the customer loyalty dataframe, you might be able to find patterns or trends in customer behaviour that could explain why some clients are more devoted to your business than others. For instance, you might discover that clients who spend more money on a product are more devoted than those who spend less money.
