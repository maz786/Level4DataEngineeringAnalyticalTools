-- %% [markdown]
-- **<u>Top ten salesman</u>**

-- %%
SELECT Employees.FirstName, Employees.LastName, SUM(Sales.Quantity) AS TotalSales
FROM Employees
INNER JOIN Sales ON Employees.EmployeeID = Sales.SalesPersonID
GROUP BY Employees.FirstName, Employees.LastName
ORDER BY TotalSales DESC
-- Out:
-- (23 rows affected)
-- Total execution time: 00:00:00.076
-- ...

-- %%
SELECT Employees.FirstName, Employees.LastName, SUM(Sales.Quantity) AS TotalSales
FROM Employees
INNER JOIN Sales ON Employees.EmployeeID = Sales.SalesPersonID
GROUP BY Employees.FirstName, Employees.LastName
ORDER BY TotalSales DESC
-- Out:
-- (23 rows affected)
-- Total execution time: 00:00:00.009
-- ...

-- %%
import pandas as pd
import matplotlib.pyplot as plt

customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

sales_employees_df = pd.merge(sales_df, employees_df, left_on='SalesPersonID', right_on='EmployeeID')

sales_by_salesperson = sales_employees_df.groupby(['FirstName', 'LastName'])['Quantity'].sum().reset_index()

sales_by_salesperson.sort_values('Quantity', ascending=False).head(10).plot(x='FirstName', y='Quantity', kind='bar', legend=None)
plt.xlabel('Salesperson')
plt.ylabel('Quantity Sold')
plt.title('Top Ten Salesmen')
plt.show()

-- %% [markdown]
-- You may visualise the top ten salesmen based on how many items they have sold using the code. The name of each salesperson will be displayed on the x-axis of the bar plot, and the number of products sold will be displayed on the y-axis. The heights of the bars on the plot will reflect how many items each salesperson sold.
--
--
--
-- This data may help a business identify its top sales representatives, as well as comprehend general sales patterns and pinpoint areas in need of improvement. A business might, for instance, utilise this data to identify salespeople who consistently outperform their peers and research potential causes of their success. Alternately, the business might utilise this data to spot any salespeople who could be having trouble, and then try to pinpoint any potential problems or areas for development that might assist them enhance their sales performance.

-- %% [markdown]
-- **<u>Top ten selling products</u>**

-- %%
SELECT TOP 10 Products.Name, SUM(Sales.Quantity) AS TotalSales
FROM Products
INNER JOIN Sales ON Products.ProductID = Sales.ProductID
GROUP BY Products.Name
ORDER BY TotalSales DESC
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.033
-- <table><tr><th>Name</th><th>TotalSales</th></tr><tr><td>Internal Lock Washer 1</td><td>25</td></tr><tr><td>HL Mountain Frame - Black 46</td><td>24</td></tr><tr><td>Lock Washer 10</td><td>23</td></tr><tr><td>Lock Ring</td><td>20</td></tr><tr><td>Hex Nut 4</td><td>18</td></tr><tr><td>Mountain-500 Silver 48</td><td>18</td></tr><tr><td>Handlebar Tube</td><td>17</td></tr><tr><td>Hex Nut 22</td><td>17</td></tr><tr><td>LL Road Seat/Saddle</td><td>17</td></tr><tr><td>Classic Vest M</td><td>16</td></tr></table>

-- %%
SELECT TOP 10 Products.Name, SUM(Sales.Quantity) AS TotalSales
FROM Products
INNER JOIN Sales ON Products.ProductID = Sales.ProductID
GROUP BY Products.Name
ORDER BY TotalSales DESC
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.020
-- <table><tr><th>Name</th><th>TotalSales</th></tr><tr><td>Internal Lock Washer 1</td><td>25</td></tr><tr><td>HL Mountain Frame - Black 46</td><td>24</td></tr><tr><td>Lock Washer 10</td><td>23</td></tr><tr><td>Lock Ring</td><td>20</td></tr><tr><td>Hex Nut 4</td><td>18</td></tr><tr><td>Mountain-500 Silver 48</td><td>18</td></tr><tr><td>Handlebar Tube</td><td>17</td></tr><tr><td>Hex Nut 22</td><td>17</td></tr><tr><td>LL Road Seat/Saddle</td><td>17</td></tr><tr><td>Classic Vest M</td><td>16</td></tr></table>

-- %%
import pandas as pd
import matplotlib.pyplot as plt

customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

sales_products_df = pd.merge(sales_df, products_df, on='ProductID')

product_sales_df = sales_products_df.groupby('Name')['Quantity'].sum().reset_index()

product_sales_df = product_sales_df.sort_values('Quantity', ascending=False)

top_ten_products_df = product_sales_df.head(10)

plt.bar(top_ten_products_df['Name'], top_ten_products_df['Quantity'])
plt.xlabel('Product Name')
plt.ylabel('Quantity Sold')
plt.title('Top Ten Selling Products')
plt.show()

-- %% [markdown]
-- Depending on the context, this information might be applied to a number of different things. These are some possible use for this data:
--
-- - Finding the most popular products: Using this data, one may determine which products are the most sought-after and possibly devote more resources to promoting or stocking them.
-- - Evaluation of sales performance: It would be able to evaluate sales performance by contrasting the volume of sales of various products and determining which products are performing well or poorly. This could help decision-makers decide which products to keep carrying and which to stop.
-- - Analysis of sales patterns: By monitoring the volume of sales of various products over time, it would be feasible to spot sales trends and perhaps even predict future sales. Making decisions concerning production and inventory management may be influenced by this.
-- - Evaluation of salesperson performance: It would be feasible to assess each salesperson's performance and determine which salespeople are the most successful at promoting various products by connecting the sales data with the employee data. This may help in making judgements about hiring, advancements, and other HR-related issues.
--
-- Overall, as this code provides a snapshot of the sales performance of various products, the data produced by it may be helpful for a variety of commercial and operational decisions.

-- %% [markdown]
-- **<u>Top five selling products</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt

customers_df = pd.read_csv("/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv")
sales_df = pd.read_csv("/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv")
employees_df = pd.read_csv("/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv")
products_df = pd.read_csv("/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv")

sales_products_df = pd.merge(sales_df, products_df, on="ProductID")

product_sales_df = sales_products_df.groupby(["ProductID", "Name"])["Quantity"].sum()

top_five_products_df = product_sales_df.sort_values(ascending=False).head(5)

top_five_products_df.plot(kind="bar", title="Top Five Selling Products")
plt.xlabel("Product")
plt.ylabel("Quantity Sold")
plt.show()

-- %% [markdown]
-- **<u>Top ten customers</u>**

-- %%
SELECT TOP 10 Customers.FirstName, Customers.LastName, SUM(Sales.Quantity) AS TotalSales
FROM Customers
INNER JOIN Sales ON Customers.CustomerID = Sales.CustomerID
GROUP BY Customers.FirstName, Customers.LastName
ORDER BY TotalSales DESC
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.035
-- <table><tr><th>FirstName</th><th>LastName</th><th>TotalSales</th></tr><tr><td>Suzanne</td><td>Yang</td><td>27</td></tr><tr><td>Katelyn</td><td>Young</td><td>27</td></tr><tr><td>Gilbert</td><td>Yang</td><td>25</td></tr><tr><td>Sandra</td><td>Yang</td><td>25</td></tr><tr><td>Amanda</td><td>Young</td><td>25</td></tr><tr><td>Brendan</td><td>Yuan</td><td>23</td></tr><tr><td>Connor</td><td>Yang</td><td>20</td></tr><tr><td>Alisha</td><td>Yuan</td><td>20</td></tr><tr><td>Alvin</td><td>Yuan</td><td>20</td></tr><tr><td>Steve</td><td>Yang</td><td>19</td></tr></table>

-- %%
SELECT TOP 10 Customers.FirstName, Customers.LastName, SUM(Sales.Quantity) AS TotalSales
FROM Customers
INNER JOIN Sales ON Customers.CustomerID = Sales.CustomerID
GROUP BY Customers.FirstName, Customers.LastName
ORDER BY TotalSales DESC
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.008
-- <table><tr><th>FirstName</th><th>LastName</th><th>TotalSales</th></tr><tr><td>Suzanne</td><td>Yang</td><td>27</td></tr><tr><td>Katelyn</td><td>Young</td><td>27</td></tr><tr><td>Gilbert</td><td>Yang</td><td>25</td></tr><tr><td>Sandra</td><td>Yang</td><td>25</td></tr><tr><td>Amanda</td><td>Young</td><td>25</td></tr><tr><td>Brendan</td><td>Yuan</td><td>23</td></tr><tr><td>Connor</td><td>Yang</td><td>20</td></tr><tr><td>Alisha</td><td>Yuan</td><td>20</td></tr><tr><td>Alvin</td><td>Yuan</td><td>20</td></tr><tr><td>Steve</td><td>Yang</td><td>19</td></tr></table>

-- %%
import pandas as pd
import matplotlib.pyplot as plt

customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

merged_df = pd.merge(customers_df, sales_df, on='CustomerID')

grouped_df = merged_df.groupby(['CustomerID', 'FirstName']).size().reset_index(name='count')

sorted_df = grouped_df.sort_values(by='count', ascending=False)

top_ten_df = sorted_df.head(10)

top_ten_df.plot(x='FirstName', y='count', kind='bar')

plt.show()

-- %% [markdown]
-- Based on the amount of purchases they have made, the data analysis demonstrated may be utilised to determine the top 10 clients and display this data in a bar chart.
--
-- The organisation might gain from visualising the top 10 clients according to the number of transactions they have made in a number of ways. For instance:
--
-- - It might assist the business in identifying its most valued clients so that it can concentrate its marketing efforts on keeping and expanding their business.
-- - It can enable the business to target particular customer groups or demographics and develop more lucrative product or service offerings.
-- - It might assist the business in spotting patterns in consumer behaviour and using that knowledge to improve its sales and marketing tactics.
-- - By identifying client segments that are not making purchases as regularly as others, it might assist the organisation in identifying potential problems or areas for improvement in its sales process.

-- %% [markdown]
-- **<u>Total sales by employee</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Calculate the total sales for each employee
employee_sales = sales_df.groupby('SalesPersonID')['Quantity'].sum()

# Plot the total sales by employee using a bar plot
plt.figure(figsize=(10,5))
sns.barplot(x=employee_sales.index, y=employee_sales.values)
plt.xlabel('Employee ID')
plt.ylabel('Total Sales')
plt.title('Total Sales by Employee')
plt.show()

-- %% [markdown]
-- By using a bar plot with the Employee ID on the x-axis and the Total Sales on the y-axis, the visualisation produced by the provided Python code would display the total sales generated by each employee. The business may use this data to identify which employees are generating the most revenue and perhaps devote more resources or give those employees more support to boost their productivity. Additionally, it might be utilised to spot any underperforming staff members and put plans in place to raise their sales output. The business may also use this data to evaluate the effectiveness of the sales force as a whole and decide how best to allocate resources or optimise sales methods.

-- %% [markdown]
-- **<u>Price vs Quantity</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Merge the Sales and Products DataFrames to get the product prices
sales_products_df = pd.merge(sales_df, products_df, on='ProductID')

# Plot the relationship between price and quantity sold using a scatter plot
plt.figure(figsize=(10,5))
sns.scatterplot(x='Price', y='Quantity', data=sales_products_df)
plt.xlabel('Price')
plt.ylabel('Quantity Sold')
plt.title('Price vs Quantity Sold')
plt.show()

-- %% [markdown]
-- A scatter plot that depicts the link between a product's price and the number of units sold will be the visualisation created by the aforementioned code. This scatter plot can give you information about the sales of various products.
--
--
--
-- You might be able to determine, for instance, whether there is a correlation between a product's price and the number of units sold. You might see, for instance, that things with higher costs typically sell in smaller quantities or that products with lower prices typically sell in bigger quantities. Additionally, you might be able to spot any outliers, or data points that stand out substantially from the rest of the data.

-- %% [markdown]
-- **<u>Total sales by customers</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Merge the Sales and Customers DataFrames to get the customer names
sales_customers_df = pd.merge(sales_df, customers_df, on='CustomerID')

# Calculate the total sales for each customer
customer_sales = sales_customers_df.groupby('LastName')['Quantity'].sum()

# Plot the total sales by customer using a bar plot
plt.figure(figsize=(10,5))
sns.barplot(x=customer_sales.index, y=customer_sales.values)
plt.xlabel('Customer Last Name')
plt.ylabel('Total Sales')
plt.title('Total Sales by Customer')
plt.show()

-- %% [markdown]
-- The visualisation produced by the provided code will display the aggregate sales for each client, organised by client last name. The company could benefit from this knowledge in a number of ways:
--
--
--
-- Finding the most valuable customers: Using the visualisation, the business might determine the clients who have made the most purchases and concentrate on keeping and gratifying them.
--
--
--
-- Finding patterns in customer behaviour: The business was able to find patterns in customer behaviour over time by examining the total sales for each customer. For instance, the business could look for patterns in the types of things that customers frequently buy or determine whether specific customers have a tendency to buy more frequently at particular periods of the year.
--
--
--
-- Evaluating the performance of sales staff: The business might use the visualisation to assess the efficiency of various sales personnel by connecting the sales data to the employee data. To determine which employees are more successful at closing sales, the organisation might, for instance, compare the total sales of individuals with comparable job titles or responsibilities.
--
--
--
-- Finding possibilities for upselling and cross-selling to customers: By displaying which customers have made the most purchases and which goods they have purchased most frequently, the visualisation may assist the business in finding opportunities for upselling or cross-selling to customers. The corporation might use this information to adapt its marketing initiatives to focus on particular clients and goods.

-- %% [markdown]
-- **<u>Distribution of sales by product</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Calculate the total sales for each product
product_sales = sales_df.groupby('ProductID')['Quantity'].sum()

# Plot the distribution of sales by product using a pie chart
plt.figure(figsize=(10,5))
plt.pie(product_sales.values, labels=product_sales.index, autopct='%1.1f%%')
plt.title('Distribution of Sales by Product')
plt.show()

-- %% [markdown]
-- The corporation might learn which products are the most well-liked and financially successful from this visualisation. Business decisions such as which products to maintain in stock, which products to promote most aggressively, and which products to maybe eliminate if they are not doing well could all be informed by this data. Any discrepancies in sales between different items might be revealed by the visualisation, which could then be studied to determine likely causes and guide the development of improvement strategies for sales performance.

-- %% [markdown]
-- **<u>Distribution of product prices</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Plot the distribution of product prices using a box plot
plt.figure(figsize=(10,5))
sns.boxplot(products_df['Price'])
plt.xlabel('Price')
plt.title('Distribution of Product Prices')
plt.show()
-- Out:
-- /Users/maz/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
--   warnings.warn(

-- %% [markdown]
-- A box plot illustrating the price distribution of products in the Products database will be displayed in the visualisation you are creating using the code you supplied. The following are some ways that the company could profit from this visualisation:
--
--
--
-- It can assist the business in comprehending the pricing range for its goods and locating any outliers that may be markedly greater or cheaper than the rest of the merchandise.
--
--
--
-- It can assist the business in figuring out the average cost of its goods, which is helpful in developing pricing policies and judging the relative worth of various goods.
--
--
--
-- In order to make wise decisions about pricing strategies and product development, it can assist the business in identifying any patterns or trends in the distribution of product prices.
--
--
--
-- It can assist the business in comparing the costs of its goods to those of its rivals and spotting any potential chances to distinguish its goods through pricing.
--
--
--
-- The corporation can learn useful information by examining the price distribution of its items that can guide business decisions and help them comprehend their goods and the market they serve.

-- %% [markdown]
-- **<u>Distribution of sales by employee</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Calculate the total sales for each employee
employee_sales = sales_df.groupby('SalesPersonID')['Quantity'].sum()

# Plot the distribution of sales by employee using a pie chart
plt.figure(figsize=(10,5))
plt.pie(employee_sales.values, labels=employee_sales.index, autopct='%1.1f%%')
plt.title('Distribution of Sales by Employee')
plt.show()

-- %% [markdown]
-- The visualisation produced by this command could serve the business in a number of ways. For instance, it might assist the business in determining which employees are contributing to the most sales and any staff members who might be underperforming. By using this data, underperforming staff could receive more training or support, while top performers could be commended and rewarded. The visualisation could also assist the business in identifying any trends or patterns in sales performance as well as the overall distribution of sales among its staff.

-- %% [markdown]
-- **<u>Distribution of quantities sold by customer</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Merge the Sales and Customers DataFrames to get the customer names
sales_customers_df = pd.merge(sales_df, customers_df, on='CustomerID')

# Plot the distribution of quantities sold by customer using a box plot
plt.figure(figsize=(10,5))
sns.boxplot(x='LastName', y='Quantity', data=sales_customers_df)
plt.xlabel('Customer Last Name')
plt.ylabel('Quantity Sold')
plt.title('Distribution of Quantities Sold by Customer')
plt.show()

-- %% [markdown]
-- The business might profit from this information in a variety of ways. For instance, the business could utilise this data to pinpoint clients who are very valued in terms of the volume of goods they buy. Additionally, the business might utilise this data to identify clients who could be less valuable and even target them with marketing initiatives to boost their purchase behaviour.
--
-- Additionally, the visualisation might show trends in the amounts of goods sold to various clients. For instance, if some consumers routinely buy higher amounts of things than other customers, the business can think about offering these customers special deals or promotions to entice them to keep up their high levels of purchasing activity.
--
-- Overall, the visualisation produced by executing the provided Python code may offer insightful information about the consumers' purchase patterns and assist the company in making defensible choices about how to engage and target them.

-- %% [markdown]
-- **<u>Total sales by employee and product</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Merge the Sales, Employees, and Products DataFrames to get the employee and product names
sales_emp_prod_df = pd.merge(sales_df, employees_df, left_on='SalesPersonID', right_on='EmployeeID')
sales_emp_prod_df = pd.merge(sales_emp_prod_df, products_df, on='ProductID')

# Calculate the total sales by employee and product
sales_by_emp_prod = sales_emp_prod_df.pivot_table(index='LastName', columns='Name', values='Quantity', aggfunc='sum')

# Plot the total sales by employee and product using a stacked bar plot
plt.figure(figsize=(10,5))
sales_by_emp_prod.plot(kind='bar', stacked=True)
plt.xlabel('Employee Last Name')
plt.ylabel('Total Sales')
plt.title('Total Sales by Employee and Product')
plt.show()

-- %% [markdown]
-- The output of running the provided Python code will display the overall sales of each product broken down by employee. The corporation might gain from this information by learning which products are most popular among its employees and which employees are most successful at selling particular things. The visualisation could also assist the business in identifying potential areas for employee training or support who could be having trouble selling specific products. Overall, this visualisation may offer insightful information about the company's sales performance and assist in decision-making regarding sales strategy and personnel development.

-- %% [markdown]
-- **<u>Distrubution of sales quantities by product</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Plot the distribution of sales quantities by product using a violin plot
plt.figure(figsize=(10,5))
sns.violinplot(x='ProductID', y='Quantity', data=sales_df)
plt.xlabel('Product ID')
plt.ylabel('Quantity Sold')
plt.title('Distribution of Sales Quantities by Product')
plt.show()

-- %% [markdown]
-- The distribution of sales amounts for each product in the Sales database would be displayed by the visualisation created by the code you gave. The business might profit from this information in a variety of ways. The business may use this data, for instance, to determine which products are selling well and which are not, and then decide which things to concentrate on or drop. The business might potentially use this data to spot long-term trends in sales and decide how to spend resources or modify their marketing tactics. The business might decide how to support or reward those salespeople based on this information, as well as determine which salespeople are performing effectively and which are not.

-- %% [markdown]
-- **<u>Total sales by customer and product</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Merge the Sales, Customers, and Products DataFrames to get the customer and product names
sales_cust_prod_df = pd.merge(sales_df, customers_df, on='CustomerID')
sales_cust_prod_df = pd.merge(sales_cust_prod_df, products_df, on='ProductID')

# Calculate the total sales by customer and product
sales_by_cust_prod = sales_cust_prod_df.pivot_table(index='LastName', columns='Name', values='Quantity', aggfunc='sum')

# Plot the total sales by customer and product using a stacked bar plot
plt.figure(figsize=(10,5))
sales_by_cust_prod.plot(kind='bar', stacked=True)
plt.xlabel('Customer Last Name')
plt.ylabel('Total Sales')
plt.title('Total Sales by Customer and Product')
plt.show()

-- %% [markdown]
-- The resultant graphic would most likely display the total sales for each client, broken down by product and indexed by last name (columns labelled by product name). The height of each bar would indicate the sales for each product, and the bars would be stacked to represent the overall sales for each client.
--
--
--
-- You may be able to learn more about which clients and in what amounts are buying different products by using this visualisation. With the help of this data, it may be possible to determine customer preferences and even modify marketing or sales methods accordingly. The corporation may use the visualisation to pinpoint any particular standouts or underperformers among its clients or goods and then take the necessary steps to resolve any difficulties or build on achievements.

-- %% [markdown]
-- **<u>Total sales by customer</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Merge the Sales and Customers DataFrames to get the customer names
sales_customers_df = pd.merge(sales_df, customers_df, on='CustomerID')

# Calculate the total sales by customer
sales_by_customer = sales_customers_df.groupby('LastName')['Quantity'].sum()

# Plot the total sales by customer using a bar plot
plt.figure(figsize=(10,5))
plt.bar(sales_by_customer.index, sales_by_customer.values)
plt.xlabel('Customer Last Name')
plt.ylabel('Total Sales')
plt.title('Total Sales by Customer')
plt.show()

-- %% [markdown]
-- This code will produce a visualisation that groups each customer's sales totals by last name and displays them. The business might benefit from this information in a variety of ways. It might be used, for instance, to pinpoint the clients who are most beneficial to the company or to spot patterns in consumer spending habits. It could also be used to more precisely target marketing campaigns by concentrating on clients who have already made significant purchases. The visualisation could also be used to point out parts of the company that might be underperforming or chances for expansion.

-- %% [markdown]
-- <u>**Distribution of sales quantities**</u>

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Merge the Sales and Customers DataFrames to get the customer names
sales_customers_df = pd.merge(sales_df, customers_df, on='CustomerID')

# Calculate the total sales by customer
sales_by_customer = sales_customers_df.groupby('LastName')['Quantity'].sum()

# Plot the distribution of sales quantities using a histogram
plt.figure(figsize=(10,5))
plt.hist(sales_df['Quantity'], bins=range(0, 11))
plt.xlabel('Quantity Sold')
plt.ylabel('Number of Sales')
plt.title('Distribution of Sales Quantities')
plt.show()

-- %% [markdown]
-- This code will produce a histogram that displays the dispersion of the company's sales numbers. The most typical product sales amounts as well as any odd or outlier quantities can be determined using this data. Sales and marketing plans, as well as decisions about stocking and managing inventories, can all benefit from this knowledge. By contrasting histograms from several time periods, the business may also be able to spot trends in the distribution of sales quantities over time.

-- %% [markdown]
-- **<u>Distribution of sales quantities by employees</u>**

-- %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files into Pandas DataFrames
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Merge the Sales and Employees DataFrames to get the employee names
sales_employees_df = pd.merge(sales_df, employees_df, left_on='SalesPersonID', right_on='EmployeeID')

# Plot the distribution of sales quantities by employee using a box plot
plt.figure(figsize=(10,5))
sns.boxplot(x='LastName', y='Quantity', data=sales_employees_df)
plt.xlabel('Employee Last Name')
plt.ylabel('Quantity Sold')
plt.title('Distribution of Sales Quantities by Employee')
plt.show()

-- %% [markdown]
-- A box plot will be used to display the distribution of sales amounts for each employee in the company using the Python code you provided. The business may benefit from this in a variety of ways:
--
-- - Finding top performers: By examining the box plot, the business may discover which employees frequently have large sales volumes, a sign of strong achievers.
-- - Finding employee performance patterns: The box plot can also be used by the business to find employee performance trends over time. For instance, it might be a sign of improved performance if a worker's sales volume continuously rises over time.
-- - The box plot can also be used by the business to identify employees who would benefit from additional training or support. For instance, if a worker's sales volume continually falls below the business median, this can be a sign that they could use more coaching or help to enhance their performance.
-- - Locating departments in the company that might want more assistance: The corporation might be able to pinpoint parts of the business that could use more support to operate better by examining the distribution of sales amounts by employee. For instance, if sales volumes in a certain product category are continuously low, the business may need to think about offering more assistance or resources there.

-- %% [markdown]
-- **<u>Total sales for each employee</u>**

-- %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the Sales and Employees databases into pandas DataFrames
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')

# Merge the two DataFrames on the SalesPersonID field
merged_df = pd.merge(sales_df, employees_df, left_on='SalesPersonID', right_on='EmployeeID')

# Group the merged DataFrame by LastName and sum the Quantity field
grouped_df = merged_df.groupby('LastName').sum()

# Create a bar chart showing the total sales for each employee
grouped_df['Quantity'].plot.bar()
plt.show()

-- %% [markdown]
-- You might create a bar chart with the code above that displays the overall sales for each employee. The business might benefit from this information in a number of ways. For instance:
--
--
--
-- - It can make it easier for the business to recognise and reward high performers.
-- - It can enable the business to spot underachievers and take the necessary action to boost sales.
-- - It could aid the business in identifying patterns in workers' performance over time, such as a general rise or fall in sales.
-- - By being aware of each employee's potential for sales, the organisation may be able to allocate resources and set goals more effectively.
-- - It could assist the business in identifying any possible problems with the sales process, such as a lack of training or insufficient employee assistance.

-- %% [markdown]
-- **<u>Total quantity of each product</u>**

-- %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the Sales and Products databases into pandas DataFrames
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Merge the two DataFrames on the ProductID field
merged_df = pd.merge(sales_df, products_df, on='ProductID')

# Filter the merged DataFrame to only include rows where the Name field includes either "frame" or "mountain"
filtered_df = merged_df[merged_df['Name'].str.contains('frame|mountain', case=False)]

# Group the filtered DataFrame by Name and sum the Quantity field
grouped_df = filtered_df.groupby('Name').sum()

# Create a bar chart showing the total quantity of each product
grouped_df['Quantity'].plot.bar()
plt.show()

-- %% [markdown]
-- This code will produce a visualisation that displays the total amount of each item with the word "frame" or "mountain" in its name. The company could benefit from this knowledge in a number of ways:
--
--
--
-- It could assist them in determining which product categories (such as frames or mountain bikes) are more well-liked by their clients so that they can perhaps modify their inventory or marketing plans accordingly.
--
--
--
-- If the visualisation is run again with updated data, it might help people observe how sales of these products have evolved over time.
--
--
--
-- If the SalesPersonID field is included in the combined DataFrame and is used to classify the data, it would be possible for them to determine which salespeople are primarily responsible for the sales of these kinds of products.
--
--
--
-- If the CustomerID field is present in the combined DataFrame and is used to group the data, it might aid in identifying which customers are making these kinds of purchases.
--
--
--
-- If the Price field is included in the merged DataFrame and is used to group the data, it might be able to show them trends in the prices of these kinds of products.

-- %% [markdown]
-- **<u>Percentage of total sales of each product</u>**

-- %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the Sales and Products databases into pandas DataFrames
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Merge the two DataFrames on the ProductID field
merged_df = pd.merge(sales_df, products_df, on='ProductID')

# Group the merged DataFrame by Name and sum the Quantity field
grouped_df = merged_df.groupby('Name').sum()

# Create a pie chart showing the percentage of total sales for each product
grouped_df['Quantity'].plot.pie(autopct='%.2f')
plt.show()

-- %% [markdown]
-- The pie chart-like visualisation produced by the Python code you provided would display the percentage of overall sales for each product. The company could benefit from this knowledge in a number of ways:
--
--
--
-- By determining which products are the most well-liked and contribute the most to overall sales, the business may be able to concentrate more on promoting and selling those items.
--
--
--
-- It can highlight any underperforming goods that the business should think about dropping or promoting more vigorously.
--
--
--
-- By producing comparable visualisations at regular intervals and comparing them, it could assist the organisation in identifying trends in product popularity over time.
--
--
--
-- By comparing the overall sales value of each product (obtained by multiplying the Quantity sold by the Price) to the cost of making and distributing that product, the corporation may be able to improve pricing and product mix.
--
--
--
-- By displaying which goods are frequently bought together, it may also be valuable for locating cross-selling opportunities. For instance, the business would want to think about combining those products together or marketing them as a package if a significant portion of sales for a certain product are accompanied by sales of a particular accessory or complimentary product.

-- %% [markdown]
-- **<u>Number of puchases made by each customer</u>**

-- %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the Sales and Customers databases into pandas DataFrames
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')

# Merge the two DataFrames on the CustomerID field
merged_df = pd.merge(sales_df, customers_df, on='CustomerID')

# Group the merged DataFrame by CustomerID and count the number of SalesID field
grouped_df = merged_df.groupby('CustomerID').count()

# Create a bar chart showing the number of purchases made by each customer
grouped_df['SalesID'].plot.bar()
plt.show()

-- %% [markdown]
-- You may see how many purchases each client made by running the aforementioned code. The business might profit from this information in a variety of ways. The business might use this data, for instance, to pinpoint its most important clients and target them with special promotions or marketing efforts. The business might also utilise this data to spot patterns in consumer buying habits, such as which goods are most well-liked by particular clientele. The business might also utilise this data to monitor customer retention and spot clients who could be on the verge of leaving.

-- %% [markdown]
-- **<u>Total sales for each product and employee</u>**

-- %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the Sales, Products, and Employees databases into pandas DataFrames
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')

# Merge the Sales and Products DataFrames on the ProductID field
merged_df = pd.merge(sales_df, products_df, on='ProductID')

# Merge the merged DataFrame with the Employees DataFrame on the SalesPersonID field
merged_df = pd.merge(merged_df, employees_df, left_on='SalesPersonID', right_on='EmployeeID')

# Group the merged DataFrame by Name and LastName and sum the Quantity field
grouped_df = merged_df.groupby(['Name', 'LastName']).sum()

# Create a stacked bar chart showing the total sales for each product and employee
grouped_df['Quantity'].unstack().plot.bar(stacked=True)
plt.show()

-- %% [markdown]
-- The given code will produce a visualisation that displays the total sales for each employee and product, stacked by product. The business can benefit from this in a number of ways:
--
--
--
-- It can assist the business in determining which products are the most well-liked and profitable so that they can concentrate their marketing efforts on those items.
--
--
--
-- It can assist the business in identifying the staff members who are most successful in closing sales so that they can reward or teach them more.
--
--
--
-- It can assist the business in identifying any trends or patterns in sales, such as when a specific product or worker performs especially well.
--
--
--
-- It can assist the business in identifying any potential faults or problems with their sales process, such as when a certain product does not sell as well as anticipated or when a worker does not perform as well as their peers.
--
--
--
-- Overall, the code's creation of a visual representation of the company's sales performance can give the company useful information on how to enhance its sales and business operations.

-- %% [markdown]
-- **<u>Total sales for each product and customer</u>**

-- %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the Sales, Products, and Customers databases into pandas DataFrames
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')
customers_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Customers.csv')

# Merge the Sales and Products DataFrames on the ProductID field
merged_df = pd.merge(sales_df, products_df, on='ProductID')

# Merge the merged DataFrame with the Customers DataFrame on the CustomerID field
merged_df = pd.merge(merged_df, customers_df, on='CustomerID')

# Group the merged DataFrame by Name and LastName and sum the Quantity field
grouped_df = merged_df.groupby(['Name', 'LastName']).sum()

# Create a stacked bar chart showing the total sales for each product and customer
grouped_df['Quantity'].unstack().plot.bar(stacked=True)
plt.show()

-- %% [markdown]
-- The python code provided generated a stacked bar chart that displays the total sales for each product and client. This graph could offer the business valuable information about how well its products are selling and who is buying them.
--
--
--
-- The corporation may, for instance, use this chart to determine which of its customers and which goods are the most popular with its customers. This data could be employed to help decide which items to concentrate on promoting or upgrading, as well as which clients to spend marketing efforts on.
--
--
--
-- The graphic could also assist the business in seeing any patterns or trends in its sales data, such as seasonal variations or modifications in consumer spending habits. This can make it easier for the business to forecast and plan for future sales.
--
--
--
-- Overall, the visualisation created by the Python code you offered could be a useful tool for the business as it tries to comprehend and improve its sales performance.

-- %% [markdown]
-- **<u>Average sales price of each product</u>**

-- %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the Sales and Products databases into pandas DataFrames
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')

# Merge the two DataFrames on the ProductID field
merged_df = pd.merge(sales_df, products_df, on='ProductID')

# Group the merged DataFrame by Name and calculate the average sales price for each product
grouped_df = merged_df.groupby('Name').mean()

# Create a bar chart showing the average sales price for each product
grouped_df['Price'].plot.bar()
plt.show()

-- %% [markdown]
-- The visualisation produced by the Python code may be advantageous to the business in a number of ways:
--
--
--
-- The business might spot patterns and trends in its sales data, such as seasonal variances or changes in consumer buying habits, by displaying the sales data. To more accurately predict and prepare for upcoming sales, this information might be used.
--
--
--
-- The visualisation could assist the business in determining which of its goods are working well and which are not. Making decisions regarding which products to keep selling and which to perhaps stop selling could be done using this knowledge.
--
--
--
-- The organisation may discover top performers and pinpoint areas for improvement among unsuccessful salespeople by using the visualisation to highlight the sales performance of individual salespeople or sales teams.
--
--
--
-- The visualisation could reveal information on consumer buying patterns, including which customers are buying the most and which products they are most interested in. Specific client segments could be targeted with customised marketing campaigns using this information.
--
--
--
-- Overall, the visualisation produced by the Python code you supplied may prove to be a useful tool for the business as it attempts to analyse and enhance its sales performance.

-- %% [markdown]
-- **<u>Total sales for each product and employee</u>**

-- %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the Sales, Products, and Employees databases into pandas DataFrames
sales_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Sales.csv')
products_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Products.csv')
employees_df = pd.read_csv('/Users/maz/Library/Mobile Documents/com~apple~CloudDocs/Documents/Education/Digital Skills/Data /Level 4 Data Analytics/Week 7/Project/csv/Employees.csv')

# Merge the Sales and Products DataFrames on the ProductID field
merged_df = pd.merge(sales_df, products_df, on='ProductID')

# Merge the merged DataFrame with the Employees DataFrame on the SalesPersonID field
merged_df = pd.merge(merged_df, employees_df, left_on='SalesPersonID', right_on='EmployeeID')

# Group the merged DataFrame by Name and LastName and sum the Quantity field
grouped_df = merged_df.groupby(['Name', 'LastName']).sum()

# Create a stacked bar chart showing the total sales for each product and employee
grouped_df['Quantity'].unstack().plot.bar(stacked=True)
plt.show()

-- %% [markdown]
-- Running this Python code would produce a visualisation that displays the total revenue for each employee and product as a stacked bar chart. The product names would be listed on the chart's x-axis, and the total number of each product sold would be displayed on the y-axis. The total sales of a certain product by a specific employee are shown by each bar in the graph.
--
--
--
-- The business might learn more about each employee's sales performance and the popularity of each product by analysing this visualisation. For instance, the business might figure out which personnel are most effective at selling specific goods, and then modify its sales tactics or product lineup accordingly. The business might use this data to forecast its next marketing and sales initiatives and to spot trends in consumer purchase behaviour.
